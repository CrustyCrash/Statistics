# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('C:\\Users\\user\\Desktop\\Python\\Python\\Statistics\\datasets\\iris.csv')
df
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
only_nums = df.columns[df.dtypes!=object]
new_df = df[only_nums]

# %%
sns.heatmap(new_df.corr(), cmap="YlGnBu", annot=True)
plt.xticks(rotation=45)
plt.yticks(rotation=45)
plt.show()

# %%
sns.pairplot(new_df) # scatter matrix plot
# Out:
# c:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
pizza_df = pd.read_csv('C:\\Users\\user\\Desktop\\Python\\Python\\Statistics\\datasets\\pizza.csv')
pizza_df
# Out:
#     Promote  Sales
# 0        23    554
# 1        56   1339
# 2        34    815
# 3        25    609
# 4        67   1600
# 5        82   2000
# 6        46   1000
# 7        14    300
# 8         6    150
# 9        47   1150
# 10       52   1200
# 11       88   2000
# 12       71   1750
# 13       78   2000
# 14       66   1500
# 15       44   1000
# 16       68   1600
# 17       90   2000
# 18       22    550

# %%
pizza_df.corr()
# Out:
#           Promote     Sales
# Promote  1.000000  0.994392
# Sales    0.994392  1.000000

# %%
sns.scatterplot(data=pizza_df, x='Promote', y='Sales')
# Out:
# <Axes: xlabel='Promote', ylabel='Sales'>

# %%
X = pizza_df[['Promote']]
y = pizza_df['Sales']
lr = LinearRegression()
lr.fit(X, y)
lr.intercept_, lr.coef_
# Out:
# (5.4858653632529695, array([23.50640302]))
